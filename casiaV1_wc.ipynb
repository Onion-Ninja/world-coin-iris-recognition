# %% [markdown]
# <a href="https://colab.research.google.com/github/Onion-Ninja/world-coin-iris-recognition/blob/main/casiaV1_wc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install onnx onnxruntime pydantic==1.10.16 huggingface-hub pyyaml
# !pip install --no-deps open-iris
# Out:
# Collecting onnx
#   Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting pydantic==1.10.16
#   Downloading pydantic-1.10.16-py3-none-any.whl.metadata (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (0.35.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pydantic==1.10.16) (4.15.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.3)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (1.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (1.1.10)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading pydantic-1.10.16-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 5.9 MB/s eta 0:00:00
# Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 48.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 45.6 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: pydantic, humanfriendly, onnx, coloredlogs, onnxruntime
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.10
#     Uninstalling pydantic-2.11.10:
#       Successfully uninstalled pydantic-2.11.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.41.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.16 which is incompatible.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.16 which is incompatible.
# gradio 5.49.0 requires pydantic<2.12,>=2.0, but you have pydantic 1.10.16 which is incompatible.
# google-adk 1.14.1 requires pydantic<3.0.0,>=2.0, but you have pydantic 1.10.16 which is incompatible.
# langchain 0.3.27 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.16 which is incompatible.
# langchain-core 0.3.78 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.16 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.16 which is incompatible.
# pydantic-settings 2.11.0 requires pydantic>=2.7.0, but you have pydantic 1.10.16 which is incompatible.
# mcp 1.16.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 1.10.16 which is incompatible.
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.19.1 onnxruntime-1.23.1 pydantic-1.10.16
# Collecting open-iris
#   Downloading open_iris-1.9.7-py3-none-any.whl.metadata (12 kB)
# Downloading open_iris-1.9.7-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: open-iris
# Successfully installed open-iris-1.9.7

# %%
import iris

print(iris.__version__)
# Out:
# 1.9.7

# %%
# Upload CASIA.zip
# Unzip CASIA V1
# !unzip -q /content/CASIA1.zip

# %%
import cv2
import matplotlib.pyplot as plt

img_pixels = cv2.imread("/content/CASIA1/1/001_1_1.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_pixels, cmap='gray')

# %%
iris_pipeline = iris.IRISPipeline()
output = iris_pipeline(iris.IRImage(img_data=img_pixels, image_id="image_id", eye_side="right"))
output.keys()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# iris_semseg_upp_scse_mobilenetv2.onnx:   0%|          | 0.00/56.1M [00:00<?, ?B/s]
# dict_keys(['error', 'iris_template', 'metadata'])

# %%
# Verify IRISPipeline inference call finished without any exception being raised
output["error"] is None
# Out:
# True

# %%
"""Available fields in `output["iris_template"]` are: """ + str(output["iris_template"].__fields__)
# Out:
# 'Available fields in `output["iris_template"]` are: {\'iris_codes\': ModelField(name=\'iris_codes\', type=List[ndarray], required=True), \'mask_codes\': ModelField(name=\'mask_codes\', type=List[ndarray], required=True), \'iris_code_version\': ModelField(name=\'iris_code_version\', type=str, required=True)}'

# %%
num_codes = len(output["iris_template"].iris_codes)
code_shape = output["iris_template"].iris_codes[0].shape

f"""Number of returned iris codes is equal to {num_codes} and each code shape is {code_shape}"""
# Out:
# 'Number of returned iris codes is equal to 2 and each code shape is (16, 256, 2)'

# %%
output["metadata"]
# Out:
# {'iris_version': '1.9.7',
#  'image_id': 'image_id',
#  'image_size': (320, 280),
#  'eye_side': 'right',
#  'eye_centers': {'iris_center': (177.48051808205966, 137.2971728148795),
#   'pupil_center': (181.94742545330357, 134.7162782201269)},
#  'pupil_to_iris_property': {'pupil_to_iris_diameter_ratio': 0.3878222863041983,
#   'pupil_to_iris_center_dist_ratio': np.float64(0.05217582718863587)},
#  'offgaze_score': 3.73082000888141e-05,
#  'eye_orientation': np.float64(-0.055496199848637406),
#  'occlusion90': np.float64(0.8218605004944094),
#  'occlusion30': np.float64(0.9825064726051361),
#  'iris_bbox': {'x_min': 79.08786010742188,
#   'y_min': 38.76966857910156,
#   'x_max': 276.2251281738281,
#   'y_max': 235.930908203125},
#  'sharpness_score': 1681.1151123046875}

# %% [markdown]
# ## Debug Env

# %%
iris_pipeline = iris.IRISPipeline(env=iris.IRISPipeline.DEBUGGING_ENVIRONMENT)

output = iris_pipeline(iris.IRImage(img_data=img_pixels, image_id="image_id", eye_side="right"))

# %%
output.keys()
# Out:
# dict_keys(['iris_template', 'metadata', 'segmentation_map', 'segmentation_binarization', 'extrapolated_polygons', 'normalized_iris', 'iris_response', 'iris_response_refined', 'error'])

# %%
iris_visualizer = iris.visualisation.IRISVisualizer()

# %%
import matplotlib.pyplot as plt

canvas = iris_visualizer.plot_ir_image(iris.IRImage(img_data=img_pixels, eye_side="right"))
plt.show()

canvas = iris_visualizer.plot_iris_template(output["iris_template"])
plt.show()

# %%
iris_pipeline.call_trace['segmentation']
# Out:
# SegmentationMap(predictions=array([[[5.9604645e-08, 3.2782555e-07, 8.9406967e-08, 1.8477440e-06],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.9802322e-08],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.9802322e-08],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        ...,
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]]],
#       dtype=float32), index2class={0: 'eyeball', 1: 'iris', 2: 'pupil', 3: 'eyelashes'})

# %%
canvas = iris_visualizer.plot_segmentation_map(
    ir_image=iris.IRImage(img_data=img_pixels, eye_side="right"),
    segmap=iris_pipeline.call_trace['segmentation'],
)
plt.show()

# %%
canvas = iris_visualizer.plot_all_geometry(
    ir_image=iris.IRImage(img_data=img_pixels, eye_side="right"),
    geometry_polygons=iris_pipeline.call_trace['vectorization'],
    eye_orientation=iris_pipeline.call_trace['eye_orientation'],
    eye_center=iris_pipeline.call_trace['eye_center_estimation'],
)
plt.show()

# %%
canvas = iris_visualizer.plot_all_geometry(
    ir_image=iris.IRImage(img_data=img_pixels, eye_side="right"),
    geometry_polygons=iris_pipeline.call_trace['geometry_estimation'],
    eye_orientation=iris_pipeline.call_trace['eye_orientation'],
    eye_center=iris_pipeline.call_trace['eye_center_estimation'],
)
plt.show()

# %%
canvas = iris_visualizer.plot_normalized_iris(
    normalized_iris=iris_pipeline.call_trace['normalization'],
)
plt.show()

# %%
canvas = iris_visualizer.plot_iris_template(
    iris_template=iris_pipeline.call_trace['encoder'],
)
plt.show()

# %% [markdown]
# # CASIA V1 Dataset

# %%
## Helper functions to run the pipeline
# Scans the dataset and returns all the filenames along with their metadata USER ID, Eye Side, Session Number = optional for CASIA V1
import os
import re

# Takes the filename as input and parses out the User ID, Image Number, SessionNo/EyeSide
def parse_filename(filename, database = "CASIAV1"):
  base = os.path.basename(filename)
  name, extension = os.path.splitext(base)

  match = re.match(r"(\d{3})_(\d)_(\d+)", name)
  if not match:
    raise ValueError(f"Invalid filename format: {filename}")

  user_id, session_number, image_number = match.groups()
  eye_side = "none"
  return {
    "user_id": user_id,
    "session_number": session_number,
    "image_number": image_number,
    "eye_side": eye_side
  }

# Takes the directory path as input
# Returns a dictionary of All image filepaths, and file metadata
def scan_files(path = "/content/CASIA1"):
  allfiles = []
  user_ids =set()

  for root, dirs, files in os.walk(path):
    for f in files:
      if f.lower().endswith(('.jpg', '.png', '.jpeg', '.bmp')):
        full_path = os.path.join(root, f)
        try:
          meta = parse_filename(f)
          meta["filepath"] = full_path
          allfiles.append(meta)
          user_ids.add(meta["user_id"])
        except ValueError as e:
          print(f"Skipping {full_path}: {e}")
  return allfiles, sorted(list(user_ids))


file_metadata = parse_filename("/content/001_1_1.jpg")
print(file_metadata)
# Out:
# {'user_id': '001', 'session_number': '1', 'image_number': '1', 'eye_side': 'none'}

# %%
allfiles, user_ids = scan_files()
print(allfiles)
print(user_ids)
# Out:
# [{'user_id': '102', 'session_number': '2', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_2_2.jpg'}, {'user_id': '102', 'session_number': '1', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_1_2.jpg'}, {'user_id': '102', 'session_number': '2', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_2_3.jpg'}, {'user_id': '102', 'session_number': '2', 'image_number': '4', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_2_4.jpg'}, {'user_id': '102', 'session_number': '2', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_2_1.jpg'}, {'user_id': '102', 'session_number': '1', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_1_1.jpg'}, {'user_id': '102', 'session_number': '1', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/102/102_1_3.jpg'}, {'user_id': '058', 'session_number': '2', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_2_3.jpg'}, {'user_id': '058', 'session_number': '1', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_1_3.jpg'}, {'user_id': '058', 'session_number': '2', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_2_1.jpg'}, {'user_id': '058', 'session_number': '2', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_2_2.jpg'}, {'user_id': '058', 'session_number': '1', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_1_1.jpg'}, {'user_id': '058', 'session_number': '1', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_1_2.jpg'}, {'user_id': '058', 'session_number': '2', 'image_number': '4', 'eye_side': 'none', 'filepath': '/content/CASIA1/58/058_2_4.jpg'}, {'user_id': '043', 'session_number': '2', 'image_number': '4', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_2_4.jpg'}, {'user_id': '043', 'session_number': '1', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_1_1.jpg'}, {'user_id': '043', 'session_number': '2', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_2_1.jpg'}, {'user_id': '043', 'session_number': '2', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_2_3.jpg'}, {'user_id': '043', 'session_number': '1', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_1_3.jpg'}, {'user_id': '043', 'session_number': '1', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_1_2.jpg'}, {'user_id': '043', 'session_number': '2', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/43/043_2_2.jpg'}, {'user_id': '056', 'session_number': '1', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_1_1.jpg'}, {'user_id': '056', 'session_number': '2', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_2_2.jpg'}, {'user_id': '056', 'session_number': '1', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_1_2.jpg'}, {'user_id': '056', 'session_number': '2', 'image_number': '4', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_2_4.jpg'}, {'user_id': '056', 'session_number': '2', 'image_number': '1', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_2_1.jpg'}, {'user_id': '056', 'session_number': '1', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_1_3.jpg'}, {'user_id': '056', 'session_number': '2', 'image_number': '3', 'eye_side': 'none', 'filepath': '/content/CASIA1/56/056_2_3.jpg'}, {'user_id': '085', 'session_number': '2', 'image_number': '4', 'eye_side': 'none', 'filepath': '/content/CASIA1/85/085_2_4.jpg'}, {'user_id': '085', 'session_number': '1', 'image_number': '2', 'eye_side': 'none', 'filepath': '/content/CASIA1/85/085_1_2.jpg'}, {'user_id': '085', 'session_number': '2', 'image_number': '2', 'eye_side': 'none', 'filepath ...
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '100', '101', '102', '103', '104', '105', '106', '107', '108']

# %%
def ensure_dir(path):
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

# %%
from tqdm import tqdm
# function that runs the whole pipeline
def pipeline(dataset_path = "/content/CASIA1", save_visuals = True, save_embeddings = False):

  ## Main Pipeline to run the model on all images
  print(f"Scanning Dataset {dataset_path}")
  files, user_ids = scan_files(dataset_path)
  print(f"Found {len(files)} files")

  # init debug env
  print("Initialising Iris Pipeline")
  iris_pipeline = iris.IRISPipeline(env=iris.IRISPipeline.DEBUGGING_ENVIRONMENT)

  # init visualizer
  print("Initialising Iris Visualizer")
  iris_visualizer = iris.visualisation.IRISVisualizer()

  # Step 3: Prepare output dirs
  output_dir = os.path.join("/content", "outputs")
  seg_dir = os.path.join(output_dir, "segmentation")
  norm_dir = os.path.join(output_dir, "normalized")
  temp_dir = os.path.join(output_dir, "templates")
  code_dir = os.path.join(output_dir, "codes")

  print(output_dir, seg_dir, norm_dir, temp_dir)

  # Ensure folders exists
  if save_visuals:
    ensure_dir(seg_dir)
    ensure_dir(norm_dir)
    ensure_dir(temp_dir)
    ensure_dir(code_dir)

  results = []

  print(f"Fields: {files[0].keys()}")
  for file_meta in tqdm(files, desc="Processing iris images"):
    img_path = file_meta["filepath"]
    filename = os.path.basename(img_path)
    name, _ = os.path.splitext(filename)

    try:
      image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
      if image is None:
        raise IOError(f"Could not read Image {img_path}")
      iris_image = iris.IRImage(img_data=image, image_id=name, eye_side="left")
      output = iris_pipeline(iris_image)
      # Save seg result:
      seg_path = os.path.join(seg_dir, f"{name}_segmentation.jpg")
      norm_path = os.path.join(norm_dir, f"{name}_normalized.jpg")
      temp_path = os.path.join(temp_dir, f"{name}_template.npz")
      code_path = os.path.join(code_dir, f"{name}_code.jpg")
      if save_visuals:
        # Save segmentation result
        canvas = iris_visualizer.plot_segmentation_map(
            ir_image=iris.IRImage(img_data=img_pixels, eye_side="right"),
            segmap=iris_pipeline.call_trace['segmentation'],
        )
        plt.savefig(seg_path, bbox_inches='tight')
        plt.clf()
        # Save normalization result
        canvas = iris_visualizer.plot_normalized_iris(
            normalized_iris=iris_pipeline.call_trace['normalization'],
            )
        plt.savefig(norm_path, bbox_inches='tight')
        plt.clf()

        # Save printed Templates
        canvas = iris_visualizer.plot_iris_template(
            iris_template=iris_pipeline.call_trace['encoder'],
        )
        plt.savefig(code_path, bbox_inches='tight')
        plt.clf()

        # Save templates as npz
        iris_code = output['iris_template'].iris_codes[0]
        mask_code = output['iris_template'].iris_codes[1]
        np.savez_compressed(temp_path, iris_code = iris_code, mask_code = mask_code)
    except Exception as e:
      print(f"Error processing {img_path}: {e}")

# %%
pipeline()
# Out:
# Scanning Dataset /content/CASIA1
# Found 756 files
# Initialising Iris Pipeline
# Initialising Iris Visualizer
# /content/outputs /content/outputs/segmentation /content/outputs/normalized /content/outputs/templates
# Fields: dict_keys(['user_id', 'session_number', 'image_number', 'eye_side', 'filepath'])
# Processing iris images:   1%|          | 6/756 [00:24<50:12,  4.02s/it]/usr/local/lib/python3.12/dist-packages/iris/utils/visualisation.py:546: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(*subplot_size)
# Processing iris images:  70%|██████▉   | 529/756 [37:11<13:55,  3.68s/it]
# Error processing /content/CASIA1/29/029_2_3.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris images:  70%|███████   | 532/756 [37:22<13:35,  3.64s/it]
# Error processing /content/CASIA1/29/029_2_1.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris images:  81%|████████  | 610/756 [42:55<09:18,  3.83s/it]
# Error processing /content/CASIA1/88/088_2_4.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris images:  81%|████████  | 611/756 [42:58<08:28,  3.51s/it]
# Error processing /content/CASIA1/88/088_2_1.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris images:  81%|████████  | 614/756 [43:10<08:36,  3.64s/it]
# Error processing /content/CASIA1/88/088_1_1.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris images:  81%|████████▏ | 615/756 [43:14<08:20,  3.55s/it]
# Error processing /content/CASIA1/88/088_1_2.jpg: 'NoneType' object has no attribute 'normalized_image'
# Processing iris
2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/085_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/054_2_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/082_2_1_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/066_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/102_1_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/057_2_4_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/018_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/058_1_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/088_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/107_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/002_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/069_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/103_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/087_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/006_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/041_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/031_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/054_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/044_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/017_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/104_1_1_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/006_1_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/085_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/108_2_4_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/053_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/071_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/087_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/087_1_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/062_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/105_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/053_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/074_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/064_1_1_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/050_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/027_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/101_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/080_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/096_2_1_segmentation.jpg (deflated 11%)
#   adding: content/outputs/segmentation/097_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/011_2_2_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/103_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/041_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/082_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/013_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/070_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/059_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/030_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/099_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/065_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/075_2_2_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/070_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/017_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/078_1_2_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/069_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/035_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/061_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/011_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/043_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/068_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/010_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/052_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/018_2_4_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/023_2_4_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/069_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/063_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/015_2_1_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/011_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/043_1_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/081_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/028_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/091_2_4_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/053_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/071_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/026_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/092_2_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/019_1_2_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/106_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/076_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/039_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/022_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/034_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/067_1_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/019_2_3_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/070_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/001_2_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/003_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/031_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/099_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/015_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/042_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/033_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/090_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/107_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/051_2_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/052_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/037_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/066_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/076_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/093_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/059_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/009_1_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/082_2_3_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/099_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/067_1_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/027_2_4_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/096_2_4_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/062_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/003_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/079_2_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/042_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/017_2_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/029_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/026_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/007_2_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/085_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/016_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/096_1_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/074_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/043_2_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/057_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/048_2_4_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/043_2_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/064_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/051_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/023_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/072_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/008_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/015_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/025_2_3_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/050_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/035_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/019_2_2_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/054_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/068_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/001_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/084_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/029_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/049_1_3_segmentation.jpg (deflated 8%)
#   adding: content/outputs/segmentation/083_1_2_segmentation.jpg (deflated 11%)
#   adding: content/outputs/segmentation/056_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/075_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/064_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/001_1_1_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/024_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/020_2_2_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/070_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/038_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/001_2_4_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/012_1_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/079_2_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/024_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/039_2_1_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/084_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/030_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/036_1_3_segmentation.jpg (deflated 10%)
#   adding: content/outputs/segmentation/035_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/081_1_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/062_2_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/012_1_2_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/013_2_3_segmentation.jpg (deflated 9%)
#   adding: content/outputs/segmentation/017_1_2_segmentation.jpg (deflated 9%)

# %%
print("Initialising Iris Pipeline")
iris_pipeline = iris.IRISPipeline(env=iris.IRISPipeline.DEBUGGING_ENVIRONMENT)

# init visualizer
print("Initialising Iris Visualizer")
iris_visualizer = iris.visualisation.IRISVisualizer()

image = cv2.imread("/content/Dummy/001_1_1.jpg", cv2.IMREAD_GRAYSCALE)
iris_image = iris.IRImage(img_data=image, image_id="001_1_1", eye_side="left")
output = iris_pipeline(iris_image)
# Out:
# Initialising Iris Pipeline
# Initialising Iris Visualizer

# %%
print(output.keys())
print(output['iris_template'].iris_codes[0].shape)
# Out:
# dict_keys(['iris_template', 'metadata', 'segmentation_map', 'segmentation_binarization', 'extrapolated_polygons', 'normalized_iris', 'iris_response', 'iris_response_refined', 'error'])
# (16, 256, 2)

# %%
#print(output['metadata'])
import numpy as np
#print(output['iris_template'])
iris_code = output['iris_template'].iris_codes[0]
#print(iris_code)
mask_code = output['iris_template'].iris_codes[1]
#print(mask_code)

np.savez_compressed('iris_template.npz', iris_code = iris_code, mask_code = mask_code)

# Load back
data = np.load("iris_template.npz", allow_pickle=True)
iris_code_new = data['iris_code']
mask_code_new = data['mask_code']

assert np.array_equal(iris_code, iris_code_new)
assert np.array_equal(mask_code, mask_code_new)
print("This line should be executed.")
# Out:
# This line should be executed.
